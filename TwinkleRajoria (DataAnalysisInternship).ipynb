# %%
import pandas as pd

# %%
#Loading The Dataset
df = pd.read_csv("Amazon Sale Report.csv")

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
# Data Cleaning: Check for missing values and data types
missing_values = df.isnull().sum()
data_types = df.dtypes

missing_values, data_types
# Out:
# (index                      0
#  Order ID                   0
#  Date                       0
#  Status                     0
#  Fulfilment                 0
#  Sales Channel              0
#  ship-service-level         0
#  Category                   0
#  Size                       0
#  Courier Status             0
#  Qty                        0
#  currency                7800
#  Amount                  7800
#  ship-city                 35
#  ship-state                35
#  ship-postal-code          35
#  ship-country              35
#  B2B                        0
#  fulfilled-by           89713
#  New                   128976
#  PendingS              128976
#  dtype: int64,
#  index                   int64
#  Order ID               object
#  Date                   object
#  Status                 object
#  Fulfilment             object
#  Sales Channel          object
#  ship-service-level     object
#  Category               object
#  Size                   object
# ...

# %%
# Drop irrelevant columns
df_cleaned = df.drop(columns=['New', 'PendingS'])

# %%
# Inspect the relationship between missing 'currency'/'Amount' and 'Status'
missing_amount_status = df_cleaned[df_cleaned['Amount'].isnull()]['Status'].value_counts()

# %%
# Drop rows with missing shipping details
df_cleaned = df_cleaned.dropna(subset=['ship-city', 'ship-state', 'ship-postal-code', 'ship-country'])

# %%
# Re-check missing values
missing_values_cleaned = df_cleaned.isnull().sum()

missing_amount_status, missing_values_cleaned
# Out:
# (Cancelled                       7571
#  Shipped                          208
#  Shipped - Delivered to Buyer       8
#  Shipping                           8
#  Shipped - Returned to Seller       3
#  Pending                            2
#  Name: Status, dtype: int64,
#  index                     0
#  Order ID                  0
#  Date                      0
#  Status                    0
#  Fulfilment                0
#  Sales Channel             0
#  ship-service-level        0
#  Category                  0
#  Size                      0
#  Courier Status            0
#  Qty                       0
#  currency               7798
#  Amount                 7798
#  ship-city                 0
#  ship-state                0
#  ship-postal-code          0
#  ship-country              0
#  B2B                       0
#  fulfilled-by          89691
#  dtype: int64)

# %%
# Remove 'Cancelled' orders
df_cleaned = df_cleaned[df_cleaned['Status'] != 'Cancelled']

# Re-check missing values after removing cancelled orders
missing_values_after_removal = df_cleaned.isnull().sum()

# Proceed with EDA: Generate summary statistics and initial visualizations
summary_statistics = df_cleaned.describe(include='all')

missing_values_after_removal, summary_statistics
# Out:
# (index                     0
#  Order ID                  0
#  Date                      0
#  Status                    0
#  Fulfilment                0
#  Sales Channel             0
#  ship-service-level        0
#  Category                  0
#  Size                      0
#  Courier Status            0
#  Qty                       0
#  currency                229
#  Amount                  229
#  ship-city                 0
#  ship-state                0
#  ship-postal-code          0
#  ship-country              0
#  B2B                       0
#  fulfilled-by          78220
#  dtype: int64,
#                  index             Order ID        Date   Status Fulfilment  \
#  count   110614.000000               110614      110614   110614     110614
#  unique            NaN               103041          91       12          2
#  top               NaN  403-4984515-8861958  05-02-2022  Shipped     Amazon
#  freq              NaN                   12        1761    77797      78220
# ...
